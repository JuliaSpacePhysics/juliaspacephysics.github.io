# %% [markdown]
# # Interactive Space Physics Visualization
#
# Explore data with interactive plots
#
# This tutorial demonstrates interactive visualization of space physics
# data using WebGL-powered plots. Unlike static plots, these
# visualizations allow you to pan, zoom, and explore your data directly.
#
# <a href="https://colab.research.google.com/github/JuliaSpacePhysics/juliaspacephysics.github.io/blob/gh-pages/tutorials/demo_interactive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
using Pkg
Pkg.add(["CDAWeb", "WGLMakie", "SpacePhysicsMakie"])

Pkg.add(url="https://github.com/SimonDanisch/BonitoBook.jl/")
using BonitoBook
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#      Cloning git-repo `https://github.com/SimonDanisch/BonitoBook.jl`
#     Updating git-repo `https://github.com/SimonDanisch/BonitoBook.jl`
#    Resolving package versions...
#    Installed ZipFile ───────────── v0.10.1
#    Installed ANSIColoredPrinters ─ v0.0.1
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [b416d416] + BonitoBook v0.2.0 `https://github.com/SimonDanisch/BonitoBook.jl/#main`
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [a4c015fc] + ANSIColoredPrinters v0.0.1
#   [b416d416] + BonitoBook v0.2.0 `https://github.com/SimonDanisch/BonitoBook.jl/#main`
#   [a5390f91] + ZipFile v0.10.1
# Precompiling project...
#    3161.5 ms  ✓ ANSIColoredPrinters
#    2157.5 ms  ✓ ZipFile
#    6530.8 ms  ✓ BonitoBook
#   15285.5 ms  ✓ BonitoBook → BonitoBookMakieExt
#   4 dependencies successfully precompiled in 26 seconds. 525 already precompiled.

# %%
; ls
# Out:
# sample_data

# %%
using BonitoBook
BonitoBook.book("

# %% [markdown]
# ## Interactive Time Series Plot
#
# This example loads OMNI solar wind data:

# %%
; jupyter lab
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: bundlerextension console dejavu events execute kernel
# kernelgateway kernelspec migrate nbclassic nbconvert nbextension notebook run
# server serverextension troubleshoot trust
#
# Jupyter command `jupyter-lab` not found.

# %%
using CDAWeb
using WGLMakie, SpacePhysicsMakie

t0 = "2008-09-05T10:00:00"
t1 = "2008-09-05T22:00:00"
# The `cda` string macro provides a convenient way to fetch multiple variables from CDAWeb in a single line.
tvars = cda"OMNI_HRO_1MIN/flow_speed, Pressure"
tplot(tvars, t0, t1)
# Out:
# <pre class="backtrace" style="overflow-x: auto;"><h3 style="color: red;">failed process: Process&#40;&#96;jupyter lab list --json&#96;, ProcessExited&#40;1&#41;&#41; &#91;1&#93;
# </h3><span>Stacktrace:</span><br /><span style="color: darkred; font-weight: bold;">  &#91;1&#93; pipeline_error</span><br /><span>    &#64; <a href="vscode://file/./process.jl:598">./process.jl:598</a> &#91;inlined&#93;</span><br /><span style="color: darkred; font-weight: bold;">  &#91;2&#93; run&#40;::Base.CmdRedirect; wait::Bool&#41;</span><br /><span>    &#64; Base <a href="vscode://file/./process.jl:513">./process.jl:513</a></span><br /><span style="color: darkred; font-weight: bold;">  &#91;3&#93; run</span><br /><span>    &#64; <a href="vscode://file/./process.jl:510">./process.jl:510</a> &#91;inlined&#93;</span><br /><span style="color: darkred; font-weight: bold;">  &#91;4&#93; run_cmd</span><br /><span>    &#64; ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:22 &#91;inlined&#93;</span><br /><span style="color: darkred; font-weight: bold;">  &#91;5&#93; &#40;::Bonito.var&#34;#173#176&#34;&#123;Bonito.var&#34;#run_cmd#175&#34;&#123;String&#125;&#125;&#41;&#40;io::IOBuffer&#41;</span><br /><span>    &#64; Bonito ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:23</span><br /><span style="color: darkred; font-weight: bold;">  &#91;6&#93; sprint&#40;::Function; context::Nothing, sizehint::Int64&#41;</span><br /><span>    &#64; Base <a href="vscode://file/./strings/io.jl:114">./strings/io.jl:114</a></span><br /><span style="color: darkred; font-weight: bold;">  &#91;7&#93; sprint</span><br /><span>    &#64; <a href="vscode://file/./strings/io.jl:107">./strings/io.jl:107</a> &#91;inlined&#93;</span><br /><span style="color: darkred; font-weight: bold;">  &#91;8&#93; jupyter_running_servers&#40;&#41;</span><br /><span>    &#64; Bonito ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:23</span><br /><span style="color: darkred; font-weight: bold;">  &#91;9&#93; jupyterlab_proxy_url&#40;port::Int64&#41;</span><br /><span>    &#64; Bonito ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:38</span><br /><span style="color: darkred; font-weight: bold;"> &#91;10&#93; get_server</span><br /><span>    &#64; ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:181 &#91;inlined&#93;</span><br /><span style="color: darkred; font-weight: bold;"> &#91;11&#93; get_server&#40;&#41;</span><br /><span>    &#64; Bonito ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:174</span><br /><span style="color: darkred; font-weight: bold;"> &#91;12&#93; Bonito.WebSocketConnection&#40;&#41;</span><br /><span>    &#64; Bonito ~/.julia/packages/Bonito/OJTyF/src/connection/websocket.jl:11</span><br /><span style="color: darkred; font-weight: bold;"> &#91;13&#93; IJuliaConnection</span><br /><span>    &#64; ~/.julia/packages/Bonito/OJTyF/src/connection/ijulia.jl:30 &#91;inlined&#93;</span><br /><span style="color: darkred; font-weight: bold;"> &#91;14&#93; &#40;::Bonito.var&#34;#169#170&#34;&#41;&#40;&#41;</span><br /><span>    &#64; Bonito ~/.julia/packages/Bonito/OJTyF/src/registry.jl:203</span><br /><span style="color: darkred; font-weight: bold;"> &#91;15&#93; default_type&#40;forced::Base.RefValue&#123;Union&#123;Nothing, Type&#123;…&#125;&#125;&#125;, available::Vector&#123;Pair&#123;DataType, Function&#125;&#125;&#41;</span><br /><span>    &#64; Bonito ~/.julia/packages/Bonito/OJTyF/src/registry.jl:39</span><br /><span style="color: darkred; font-weight: bold;"> &#91;16&#93; default_connection</span><br /><span>    &#64; ~/.julia/packages/Bonito/OJTyF/src/registry.jl:155 &#91;inlined&#93;</span><br /><span style="color: darkred; font-weight: bold;"> &#91;17&#93; show_html&#40;io::IOContext&#123;IOBuffer&#125;, app::Bonito.App; parent::Nothing&#41;</span><br /><span>    &#64; Bonito ~/.julia/packages/Bonito/OJTyF/src/display.jl:74</span><br /><span style="color: darkred; font-weight: bold;"> &#91;18&#93; show_html&#40;io::IOContext&#123;IOBuffer&#125;, app::Bonito.App&#41;</span><br /><span>    &#64; Bonito ~/.julia/packages/Bonito/OJTyF/src/display.jl:63</span><br /><span style="color: darkred; font-weight: bold;"> &#91;19 ...
# ┌ Error: Error rendering app
# │   exception =
# │    failed process: Process(`jupyter lab list --json`, ProcessExited(1)) [1]
# │
# │    Stacktrace:
# │      [1] pipeline_error
# │        @ ./process.jl:598 [inlined]
# │      [2] run(::Base.CmdRedirect; wait::Bool)
# │        @ Base ./process.jl:513
# │      [3] run
# │        @ ./process.jl:510 [inlined]
# │      [4] run_cmd
# │        @ ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:22 [inlined]
# │      [5] (::Bonito.var"#173#176"{Bonito.var"#run_cmd#175"{String}})(io::IOBuffer)
# │        @ Bonito ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:23
# │      [6] sprint(::Function; context::Nothing, sizehint::Int64)
# │        @ Base ./strings/io.jl:114
# │      [7] sprint
# │        @ ./strings/io.jl:107 [inlined]
# │      [8] jupyter_running_servers()
# │        @ Bonito ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:23
# │      [9] jupyterlab_proxy_url(port::Int64)
# │        @ Bonito ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:38
# │     [10] get_server
# │        @ ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:181 [inlined]
# │     [11] get_server()
# │        @ Bonito ~/.julia/packages/Bonito/OJTyF/src/server-defaults.jl:174
# │     [12] Bonito.WebSocketConnection()
# │        @ Bonito ~/.julia/packages/Bonito/OJTyF/src/connection/websocket.jl:11
# │     [13] IJuliaConnection
# │        @ ~/.julia/packages/Bonito/OJTyF/src/connection/ijulia.jl:30 [inlined]
# │     [14] (::Bonito.var"#169#170")()
# │        @ Bonito ~/.julia/packages/Bonito/OJTyF/src/registry.jl:203
# │     [15] default_type(forced::Base.RefValue{Union{Nothing, Type{<:Bonito.FrontendConnection}}}, available::Vector{Pair{DataType, Function}})
# │        @ Bonito ~/.julia/packages/Bonito/OJTyF/src/registry.jl:39
# │     [16] default_connection
# │        @ ~/.julia/packages/Bonito/OJTyF/src/registry.jl:155 [inlined]
# │     [17] show_html(io::IOContext{IOBuffer}, app::Bonito.App; parent::Nothing)
# │        @ Bonito ~/.julia/packages/Bonito/OJTyF/src/display.jl:74
# │     [18] show_html(io::IOContext{IOBuffer}, app::Bonito.App)
# │        @ Bonito ~/.julia/packages/Bonito/OJTyF/src/display.jl:63
# │     [19] show
# │        @ ~/.julia/packages/Bonito/OJTyF/src/display.jl:106 [inlined]
# │     [20] backend_show(screen::WGLMakie.Screen, io::IOContext{IOBuffer}, m::MIME{Symbol("text/html")}, scene::Scene, figure::Figure)
# │        @ WGLMakie ~/.julia/packages/WGLMakie/6mizW/src/display.jl:271
# │     [21] show(io::IOContext{IOBuffer}, m::MIME{Symbol("text/html")}, figlike::Figure; backend::Module, update::Bool)
# │        @ Makie ~/.julia/packages/Makie/Vn16E/src/display.jl:260
# │     [22] show
# │        @ ~/.julia/packages/Makie/Vn16E/src/display.jl:249 [inlined]
# │     [23] show(io::IOContext{IOBuffer}, m::MIME{Symbol("text/html")}, fg::SpacePhysicsMakie.FigureAxes)
# │        @ SpacePhysicsMakie ~/.julia/packages/SpacePhysicsMakie/At07n/src/types.jl:114
# │     [24] limitstringmime(mime::MIME{Symbol("text/html")}, x::Any, forcetext::Bool)
# │        @ IJulia ~/.julia/packages/IJulia/TXScA/src/inline.jl:56
# │     [25] limitstringmime
# │        @ ~/.julia/packages/IJulia/TXScA/src/inline.jl:51 [inlined]
# │     [26] display_mimestring(m::MIME{Symbol("text/html")}, x::Any)
# │        @ IJulia ~/.julia/packages/IJulia/TXScA/src/display.jl:80
# │     [27] display_mimestring(mime_array::Vector{MIME}, x::Any)
# │        @ IJulia ~/.julia/packages/IJulia/TXScA/src/display.jl:74
# │     [28] _display_dict(x::Any)
# │        @ IJulia ~/.julia/packages/IJulia/TXScA/src/display.jl:109
# │     [29] display_dict(x::Any)
# │        @ IJulia ~/.julia/packages/IJulia/TXScA/src/display.jl:133
# │     [30] #invokelatest#2
# │        @ ./essentials.jl:1055 [inlined]
# │     [31] invokelatest
# │        @ ./essentials.jl:1052 [inlined]
# │     [32] execute_request(socket::ZMQ.Socket, kernel::IJulia.Kernel, msg::Msg)
# │        @ IJulia ~/.julia/packages/IJulia/TXScA/src/execute_request.jl:181
# │     [33] #invokelatest#2
# │        @ ./essentials.jl:1055 [inlined]
# │     [34] invokelatest
# │        @ ./essentials.jl:1052 [inlined]
# │     [35] eventloop(socket::ZMQ.Socket, kernel::IJulia.Kernel)
# │        @ IJulia ~/.julia/packages/IJulia/TXScA/src/eventloop.jl:26
# │     [36] (::IJulia.var"#40#43"{IJulia.Kernel})()
# │        @ IJulia ~/.julia/packages/IJulia/TXScA/src/eventloop.jl:71
# └ @ Bonito ~/.julia/packages/Bonito/OJTyF/src/app.jl:43

# %% [markdown]
# Try interacting with the plot:
#
# -   **Scroll** to zoom in/out
# -   **Click and drag** to pan
# -   **ctrl+click** to reset the view
#
# See
# [SpacePhysicsMakie.jl](https://juliaspacephysics.github.io/SpacePhysicsMakie.jl/dev/speasy/)
# webpage for an example using
# [`Speasy.jl`](https://sciqlop.github.io/Speasy.jl/dev/).
